# %% [markdown]
# <center>
#
# ## Aprendizaje No Supervisado DiploDatos
#     Laura Alonso Alemany, Ana Georgina Flesia y Valeria Rulloni
# ## Agrupamiento con el FIFA 2019 dataset
#
# ![FIFA-19-Background-1-768x401.jpg](data:image/jpeg;base64,...)
#
# Material basado en notas de Ana Georgina Flesia bajo los términos y condiciones de la licencia [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/), a su vez basado de material de [SilveMel](https://www.kaggle.com/karangadiya/fifa19/downloads/data.csv/comments) y otros.

# %% [markdown]
# ### Indice de temas
# 1. [Inicialización del entorno](#1.-Inicialización-del-entorno)
# 2. [Exploración de la Base](#2.-Exploración-de-la-base)
# 3. [Preparación de los datos](#3.-Preparación-de-los-datos)
# 4. [Clustering Visual](#3.-Exploratorio-Visual-para-Clustering)

# %% [markdown]
# ## 1.-Inicialización-del-entorno

# %% [markdown]
# **Empezamos cargando algunas herramientas para cargar los datos y manipularlos.**

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',1000)
import itertools
import warnings
warnings.filterwarnings("ignore")
import io

# %% [markdown]
# **Para visualización usaremos principalmente plotly, también seaborn y matplotlib.**

# %%
from plotly.offline import init_notebook_mode, plot,iplot
import plotly.graph_objs as go
init_notebook_mode(connected=True)
import matplotlib.pyplot as plt
import plotly.tools as tls#visualization
import plotly.figure_factory as ff#visualization
import seaborn as sns
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## 2.-Exploración-de-la-base

# %% [markdown]
# **Cargamos los datos bajados de la database de [Kaggle](https://www.kaggle.com/karangadiya/fifa19) (https://www.kaggle.com/karangadiya/fifa19) como 'data.csv'.**

# %%
df=pd.read_csv("./data/players_21.csv")
df.head(4)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3     188545  https://sofifa.com/player/188545/robert-lewand...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   33  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   35  1985-02-05
# 2           J. Oblak                            Jan Oblak   27  1993-01-07
# 3     R. Lewandowski                   Robert Lewandowski   31  1988-08-21
#
#    height_cm  weight_kg nationality          club_name  \
# 0        170         72   Argentina       FC Barcelona
# 1        187         83    Portugal           Juventus
# 2        188         87    Slovenia    Atlético Madrid
# 3        184         80      Poland  FC Bayern München
#
#               league_name  league_rank  overall  potential  value_eur  \
# 0  Spain Primera Division          1.0       93         93   67500000
# 1         Italian Serie A          1.0       92         92   46000000
# 2  Spain Primera Division          1.0       91         93   75000000
# 3    German 1. Bundesliga          1.0       91         91   80000000
#
#    wage_eur player_positions preferred_foot  international_reputation  \
# 0    560000       RW, ST, CF           Left                         5
# 1    220000           ST, LW          Right                         5
# 2    125000               GK          Right                         3
# 3    240000               ST          Right                         4
#
#    weak_foot  skill_moves      work_rate             body_type real_face  \
# 0          4            4     Medium/Low                 Messi       Yes
# 1          4            5       High/Low            C. Ronaldo       Yes
# 2          3            1  Medium/Medium  PLAYER_BODY_TYPE_259       Yes
# 3          4            4    High/Medium  PLAYER_BODY_TYPE_276       Yes
#
#    release_clause_eur                                        player_tags  \
# 0         138400000.0  #Dribbler, #Distance Shooter, #FK Specialist, ...
# 1          75900000.0  #Aerial Threat, #Dribbler, #Distance Shooter, ...
# 2         159400000.0                                                NaN
# 3         132000000.0              #Distance Shooter, #Clinical Finisher
#
#   team_position  team_jersey_number loaned_from      joined  \
# 0           CAM                10.0         NaN  2004-07-01
# 1            LS                 7.0         NaN  2018-07-10
# 2            GK                13.0         NaN  2014-07-16
# 3            ST                 9.0         NaN  2014-07-01
#
#    contract_valid_until nation_position  nation_jersey_number  pace  shooting  \
# 0                2021.0              RW                  10.0  85.0      92.0
# 1                2022.0              LS                   7.0  89.0      93.0
# 2                2023.0              GK                   1.0   NaN       NaN
# 3                2023.0             NaN                   NaN  78.0      91.0
#
#    passing  dribbling  defending  physic  gk_diving  gk_handling  gk_kicking  \
# 0     91.0       95.0       38.0    65.0        NaN          NaN         NaN
# 1     81.0       89.0       35.0    77.0        NaN          NaN         NaN
# 2      NaN        NaN        NaN     NaN       87.0         92.0        78.0
# 3     78.0       85.0       43.0    82.0        NaN          NaN         NaN
#
#    gk_reflexes  gk_speed  gk_positioning  \
# 0          NaN       NaN             NaN
# 1          NaN       NaN             NaN
# 2         90.0      52.0            90.0
# 3          NaN       NaN             NaN
#
#                                        player_traits  attacking_crossing  \
# 0  Finesse Shot, Long Shot Taker (AI), Speed Drib...                  85
# 1  Power Free-Kick, Flair, Long Shot Taker (AI), ...                  84
# 2                   GK Long Throw, Comes For Crosses                  13
# 3  Solid Player, Finesse Shot, Outside Foot Shot,...                  71
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   95                          70                       91
# 1                   95                          90                       82
# 2                   11                          15                       43
# 3                   94                          85                       84
#
#    ...  movement_acceleration  movement_sprint_speed  movement_agility  \
# 0  ...                     91                     80                91
# 1  ...                     87                     91                87
# 2  ...                     43                     60                67
# 3  ...                     77                     78                77
#
#    movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 0                  94                95                86             68
# 1                  95                71                94             95
# 2                  88                49                59             78
# 3                  93                82                89             84
#
#    power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 0             72              69                94                    44
# 1             84              78                93                    63
# 2             41              78                12                    34
# 3             76              86                85                    81
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       40                     93                95
# 1                       29                     95                82
# 2                       19                     11                65
# 3                       49                     94                79
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                NaN
# 1                   84                   95                NaN
# 2                   11                   68                NaN
# 3                   88                   88                NaN
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         35                        24                   6
# 1                         32                        24                   7
# 2                         12                        18                  87
# 3                         42                        19                  15
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                    11                   15                       14
# 1                    11                   15                       14
# 2                    92                   78                       90
# 3                     6                   12                        8
#
#    goalkeeping_reflexes    ls    st    rs    lw    lf    cf    rf    rw   lam  \
# 0                     8  89+3  89+3  89+3  92+0  93+0  93+0  93+0  92+0  93+0
# 1                    11  91+1  91+1  91+1  89+0  91+0  91+0  91+0  89+0  88+3
# 2                    90  33+3  33+3  33+3  32+0  35+0  35+0  35+0  32+0  38+3
# 3                    10  89+2  89+2  89+2  85+0  87+0  87+0  87+0  85+0  85+3
#
#     cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb  \
# 0  93+0  93+0  91+2  87+3  87+3  87+3  91+2  66+3  65+3  65+3  65+3  66+3
# 1  88+3  88+3  88+3  81+3  81+3  81+3  88+3  65+3  61+3  61+3  61+3  65+3
# 2  38+3  38+3  35+3  38+3  38+3  38+3  35+3  32+3  36+3  36+3  36+3  32+3
# 3  85+3  85+3  83+3  79+3  79+3  79+3  83+3  64+3  65+3  65+3  65+3  64+3
#
#      lb   lcb    cb   rcb    rb
# 0  62+3  52+3  52+3  52+3  62+3
# 1  61+3  54+3  54+3  54+3  61+3
# 2  32+3  33+3  33+3  33+3  32+3
# 3  61+3  60+3  60+3  60+3  61+3
#
# [4 rows x 106 columns]

# %%
df.tail(4)
# Out:
#        sofifa_id                                         player_url  \
# 18940     257710  https://sofifa.com/player/257710/mengxuan-zhan...
# 18941     250989  https://sofifa.com/player/250989/zhenghao-wang...
# 18942     257697  https://sofifa.com/player/257697/zitong-chen/2...
# 18943     257936   https://sofifa.com/player/257936/yue-song/210002
#
#            short_name       long_name  age         dob  height_cm  weight_kg  \
# 18940  Zhang Mengxuan  Mengxuan Zhang   21  1999-04-26        177         70
# 18941   Wang Zhenghao             王政豪   20  2000-06-28        185         74
# 18942     Chen Zitong     Zitong Chen   23  1997-02-20        186         80
# 18943        Song Yue        Yue Song   28  1991-11-20        185         79
#
#       nationality                            club_name           league_name  \
# 18940    China PR  Chongqing Dangdai Lifan FC SWM Team  Chinese Super League
# 18941    China PR                      Tianjin TEDA FC  Chinese Super League
# 18942    China PR        Shijiazhuang Ever Bright F.C.  Chinese Super League
# 18943    China PR                      Tianjin TEDA FC  Chinese Super League
#
#        league_rank  overall  potential  value_eur  wage_eur player_positions  \
# 18940          1.0       47         52      35000      1000               CB
# 18941          1.0       47         51      35000      1000               CB
# 18942          1.0       47         51      40000      1000               CM
# 18943          1.0       47         47      30000      2000               CM
#
#       preferred_foot  international_reputation  weak_foot  skill_moves  \
# 18940          Right                         1          2            2
# 18941          Right                         1          2            2
# 18942          Right                         1          2            2
# 18943          Right                         1          2            2
#
#         work_rate body_type real_face  release_clause_eur player_tags  \
# 18940     Low/Low    Normal        No             57000.0         NaN
# 18941  Low/Medium    Normal        No             57000.0         NaN
# 18942     Low/Low      Lean        No             65000.0         NaN
# 18943     Low/Low      Lean        No             47000.0         NaN
#
#       team_position  team_jersey_number loaned_from      joined  \
# 18940           SUB                25.0         NaN  2020-08-01
# 18941           RES                 2.0         NaN  2019-02-01
# 18942           RDM                 4.0         NaN  2020-08-01
# 18943           RES                33.0         NaN  2020-08-01
#
#        contract_valid_until nation_position  nation_jersey_number  pace  \
# 18940                2020.0             NaN                   NaN  58.0
# 18941                2022.0             NaN                   NaN  51.0
# 18942                2023.0             NaN                   NaN  61.0
# 18943                2022.0             NaN                   NaN  65.0
#
#        shooting  passing  dribbling  defending  physic  gk_diving  \
# 18940      23.0     26.0       27.0       50.0    48.0        NaN
# 18941      25.0     29.0       36.0       45.0    55.0        NaN
# 18942      35.0     48.0       48.0       44.0    58.0        NaN
# 18943      37.0     49.0       46.0       40.0    59.0        NaN
#
#        gk_handling  gk_kicking  gk_reflexes  gk_speed  gk_positioning  \
# 18940          NaN         NaN          NaN       NaN             NaN
# 18941          NaN         NaN          NaN       NaN             NaN
# 18942          NaN         NaN          NaN       NaN             NaN
# 18943          NaN         NaN          NaN       NaN             NaN
#
#       player_traits  attacking_crossing  attacking_finishing  \
# 18940           NaN                  23                   16
# 18941           NaN                  20                   20
# 18942           NaN                  38                   32
# 18943           NaN                  44                   32
#
#        attacking_heading_accuracy  attacking_short_passing  ...  \
# 18940                          45                       31  ...
# 18941                          46                       40  ...
# 18942                          45                       56  ...
# 18943                          44                       56  ...
#
#        movement_acceleration  movement_sprint_speed  movement_agility  \
# 18940                     60                     56                45
# 18941                     54                     49                40
# 18942                     62                     60                59
# 18943                     67                     64                56
#
#        movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 18940                  48                70                35             65
# 18941                  45                57                35             69
# 18942                  51                53                45             56
# 18943                  44                55                49             59
#
#        power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 18940             55              45                23                    44
# 18941             58              55                22                    46
# 18942             48              63                33                    56
# 18943             54              62                34                    57
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 18940                       50                     25                25
# 18941                       45                     25                25
# 18942                       40                     31                45
# 18943                       35                     48                44
#
#        mentality_penalties  mentality_composure  defending_marking  \
# 18940                   35                   40                NaN
# 18941                   35                   40                NaN
# 18942                   42                   43                NaN
# 18943                   36                   35                NaN
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 18940                         56                        47
# 18941                         55                        45
# 18942                         49                        45
# 18943                         43                        45
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 18940                  12                    13                    8
# 18941                  12                     9                   14
# 18942                  15                     7                    7
# 18943                   8                     5                   11
#
#        goalkeeping_positioning  goalkeeping_reflexes    ls    st    rs    lw  \
# 18940                       14                     6  32+2  32+2  32+2  30+0
# 18941                       15                    13  34+2  34+2  34+2  33+0
# 18942                        5                    13  44+2  44+2  44+2  46+0
# 18943                        5                     7  46+1  46+1  46+1  47+0
#
#          lf    cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm  \
# 18940  30+0  30+0  30+0  30+0  29+2  29+2  29+2  31+2  32+2  32+2  32+2  31+2
# 18941  33+0  33+0  33+0  33+0  33+2  33+2  33+2  35+2  35+2  35+2  35+2  35+2
# 18942  45+0  45+0  45+0  46+0  47+2  47+2  47+2  47+2  47+2  47+2  47+2  47+2
# 18943  46+0  46+0  46+0  47+0  47+0  47+0  47+0   49+  47+0  47+0  47+0   49+
#
#         lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 18940  42+2  41+2  41+2  41+2  42+2  45+2  47+2  47+2  47+2  45+2
# 18941  42+2  42+2  42+2  42+2  42+2  44+2  47+2  47+2  47+2  44+2
# 18942  47+2  49+2  49+2  49+2  47+2  47+2  49+2  49+2  49+2  47+2
# 18943  47+0  47+0  47+0  47+0  47+0  47+0  46+1  46+1  46+1  47+0
#
# [4 rows x 106 columns]

# %%
print(df.columns)
print(len(df.columns))
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club_name',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=106)
# 106

# %%
df.columns.tolist()
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club_name',
#  'league_name',
#  'league_rank',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'nation_position',
#  'nation_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
#  'skill_ball_control',
#  'movement_acceleration',
#  'movement_sprint_speed',
#  'movement_agility',
#  'movement_reactions',
#  'movement_balance',
#  'power_shot_power',
#  'power_jumping',
#  'power_stamina',
#  'power_strength',
#  'power_long_shots',
#  'mentality_aggression',
#  'mentality_interceptions',
#  'mentality_positioning',
#  'mentality_vision',
#  'mentality_penalties',
#  'mentality_composure',
#  'defending_marking',
#  'defending_standing_tackle',
#  'defending_sliding_tackle',
#  'goalkeeping_diving',
#  'goalkeeping_handling',
#  'goalkeeping_kicking',
#  'goalkeeping_positioning',
#  'goalkeeping_reflexes',
#  'ls',
#  'st',
#  'rs',
#  'lw',
#  'lf',
#  'cf',
#  'rf',
#  'rw',
#  'lam',
#  'cam',
#  'ram',
#  'lm',
#  'lcm',
#  'cm',
#  'rcm',
#  'rm',
#  'lwb',
#  'ldm',
#  'cdm',
#  'rdm',
#  'rwb',
#  'lb',
#  'lcb',
#  'cb',
#  'rcb',
#  'rb']

# %% [markdown]
# La variable **'Overall'** se calcula usando otras variables de desempeño del jugador (skills_ratings).
#
# La variable 'Overall' es discreta, así como las otras de desempeño según habilidad ('Crossing',
#        'Finishing', 'HeadingAccuracy', etc.), tomando valores enteros entre 0 y 100
#
# Miramos ahora los mejores jugadores por posicion, usando las variables 'Overall' y 'Position'.

# %% [markdown]
# **Realizamos el histograma de la variable "Overall" (Desempeño global)**

# %%
df['overall'].hist(bins = 20)
# Out:
# <AxesSubplot:>

# %%
best_players_per_position=df.iloc[df.groupby(df['player_positions'])['overall'].idxmax()][['player_positions','short_name','overall']]
best_players_per_position
# Out:
#       player_positions           short_name  overall
# 340                CAM       Jonathan Viera       81
# 1032          CAM, CDM         Borja Valero       77
# 2954      CAM, CDM, CM             L. Zuffi       73
# 13364     CAM, CDM, LM            J. Flores       62
# 90             CAM, CF              M. Reus       85
# 1905       CAM, CF, CM            D. Didavi       75
# 15190      CAM, CF, LM          M. Eberwein       60
# 5608       CAM, CF, RM           K. Miyoshi       69
# 1340       CAM, CF, RW          G. Martínez       76
# 51         CAM, CF, ST             A. Gómez       86
# 5              CAM, CM         K. De Bruyne       91
# 532       CAM, CM, CDM        L. Pellegrini       79
# 79         CAM, CM, CF         Luis Alberto       85
# 762        CAM, CM, LM           M. Lanzini       78
# 133        CAM, CM, LW                 Isco       84
# 94         CAM, CM, RM           C. Eriksen       85
# 8371       CAM, CM, RW           G. Mastinu       67
# 364        CAM, CM, ST        Nuno Padrenda       81
# 13973          CAM, LB              J. Kade       61
# 1471           CAM, LM         L. Zelarayán       76
# 4791       CAM, LM, CF         C. Benavente       70
# 1274       CAM, LM, CM           R. Pizarro       76
# 2558       CAM, LM, LB         Mauro Júnior       73
# 492        CAM, LM, LW       Laure Santeiro       80
# 509        CAM, LM, RM            Dani Olmo       79
# 16872      CAM, LM, RW            J. Tilley       57
# 2412       CAM, LM, ST        Marcos Júnior       74
# 463            CAM, LW            A. Ljajić       80
# 16322      CAM, LW, CF             O. Deman       58
# 189        CAM, LW, CM             Coutinho       83
# 3212       CAM, LW, RW             M. Tolić       72
# 266        CAM, LW, ST            Q. Promes       82
# 5329           CAM, RB        Heltinho Melo       70
# 211            CAM, RM      Ronaldo Cabrais       83
# 62         CAM, RM, CF           K. Havertz       85
# 902        CAM, RM, CM         M. Ihattaren       77
# 1005       CAM, RM, LM         K. Fortounis       77
# 782        CAM, RM, LW           M. Almirón       78
# 3747       CAM, RM, RB       Kauã Abranches       72
# 58         CAM, RM, RW            T. Müller       86
# 167        CAM, RM, ST             N. Fekir       83
# 81             CAM, RW            H. Ziyech       85
# 15468      CAM, RW, CF            L. Egloff       59
# 7066       CAM, RW, CM        J. Edmundsson       68
# 2574       CAM, RW, LW           S. Amallah       73
# 1530       CAM, RW, RM          R. Orsolini       75
# 1778       CAM, RW, ST          L. Podolski       75
# 11184     CAM, RWB, CM             R. Broom       64
# 330            CAM, ST             M. Kruse       81
# 651        CAM, ST, CF              Pozuelo       79
# 4884       CAM, ST, CM            Stoichkov       70
# 691        CAM, ST, LM        Matheus Cunha       78
# 2002       CAM, ST, LW              Cesinha       75
# 2739       CAM, ST, RM              D. Saba       73
# 5064       CAM, ST, RW           R. Rodelin       70
# 8                   CB          V. van Dijk       90
# 7278           CB, CAM          K. Yamamura       68
# 13788      CB, CAM, CM        T. Lindenhahn       62
# 68             CB, CDM           Marquinhos       85
# 2094       CB, CDM, CM              Joaquín       74
# 254        CB, CDM, LB             D. Blind       82
# 3938       CB, CDM, RB          O. Karafiát       71
# 15910      CB, CDM, RM            C. Gasser       59
# 720             CB, CM        L. Dendoncker       78
# 6523       CB, CM, CDM           J. Fuentes       68
# 132             CB, LB             D. Alaba       84
# 3777       CB, LB, CDM          T. Shiotani       72
# 5062       CB, LB, LWB            G. Friend       70
# 479         CB, LB, RB      Nacho Fernández       80
# 16211           CB, LM          K. Takahata       58
# 4898           CB, LWB          J. Robinson       70
# 372             CB, RB         Éder Militão       80
# 2134       CB, RB, CDM         J. St. Juste       74
# 5030        CB, RB, CM            J. Howson       70
# 1585        CB, RB, LB            T. Jedvaj       75
# 987         CB, RB, RM         Clinton Mata       77
# 384        CB, RB, RWB       L. Klostermann       80
# 10001       CB, RB, ST          W. Janssens       65
# 17341           CB, RM          Kim Woo Suk       56
# 9621        CB, RM, RB        K. Piątkowski       65
# 12586           CB, RW         Kim Jin Hyuk       63
# 4013           CB, RWB        Vítor Tormena       71
# 7084       CB, RWB, RB           J. Cuffaut       68
# 10643      CB, RWB, RM           T. Okamoto       65
# 10394           CB, ST             Yu Dabao       65
# 7807       CB, ST, CAM               S. Mai       67
# 17                 CDM             Casemiro       89
# 2598          CDM, CAM            A. Browne       73
# 755       CDM, CAM, CM          A. Doucouré       78
# 10933     CDM, CAM, LM           J. Pereyra       64
# 328            CDM, CB        Javi Martínez       81
# 154        CDM, CB, CM           D. Zakaria       83
# 703        CDM, CB, LB          L. Martínez       78
# 8556       CDM, CB, RB            M. Oravec       66
# 12536      CDM, CB, RM          R. Tranberg       63
# 27             CDM, CM             N. Kanté       88
# 361       CDM, CM, CAM     Rosberto Dourado       81
# 534        CDM, CM, CB             Zubeldia       79
# 1052       CDM, CM, LB             F. Delph       77
# 749        CDM, CM, LM            R. Zobnin       78
# 221        CDM, CM, RB            K. Laimer       82
# 2115       CDM, CM, RM            C. Roldan       74
# 7770      CDM, CM, RWB            S. Mrowca       67
# 1141           CDM, LB            J. Hector       77
# 14871      CDM, LB, CB             A. Deuro       60
# 8283       CDM, LB, CM            T. Mokeke       67
# 13915          CDM, LM             I. Gruev       61
# 7003       CDM, LM, CM       Shin Hyung Min       68
# 20             CDM, RB           J. Kimmich       88
# 6330       CDM, RB, CB            J. Daoudi       69
# 5732       CDM, RB, CM            L. Azouni       69
# 8045       CDM, RB, LB             V. Anita       67
# 2740       CDM, RB, RM             T. Holeš       73
# 9023           CDM, RM        Ko Seung Beom       66
# 8134       CDM, RM, CM             C. Erbes       67
# 2446       CDM, RM, RB            C. Mayada       74
# 15124      CDM, RW, RB           J. Montaño       60
# 1184          CDM, RWB             T. Adams       76
# 14955          CDM, ST          A. Thurgate       60
# 47                  CF      Roberto Firmino       87
# 22             CF, CAM            P. Dybala       88
# 2441       CF, CAM, CM         Lee Jae Sung       74
# 3847       CF, CAM, LM        A. Sigurðsson       71
# 1110       CF, CAM, LW             S. Verdi       77
# 1731       CF, CAM, RW            Z. Labyad       75
# 467        CF, CAM, ST      Ricardo Goulart       80
# 803             CF, CM           K. Boateng       78
# 7798        CF, CM, LM           G. Notsuda       67
# 11226           CF, LM             Y. Asano       64
# 1401       CF, LM, CAM           A. Mehmedi       76
# 320         CF, LM, LW            F. Ribéry       81
# 10644       CF, LM, RM           T. Umesaki       65
# 1932            CF, LW       N. De Préville       75
# 72         CF, LW, CAM             M. Depay       85
# 521         CF, LW, RW           M. Rashica       79
# 1750        CF, LW, ST           F. Pizzini       75
# 8360            CF, RM         K. Shibasaki       67
# 8278        CF, RM, CM          K. Nagasawa       67
# 5814        CF, RM, RW           R. Insigne       69
# 8357       CF, RM, RWB             Y. Komai       67
# 14882       CF, RM, ST        Jabez Makanda       60
# 714             CF, RW            F. Chiesa       78
# 15              CF, ST           K. Benzema       89
# 302        CF, ST, CAM            J. Correa       81
# 6277        CF, ST, CM             H. Okuno       69
# 1059        CF, ST, LM              J. King       77
# 1237        CF, ST, LW       Alex Berenguer       76
# 5354        CF, ST, RM               S. Doi       70
# 1083        CF, ST, RW          Iago Falqué       77
# 24                  CM             T. Kroos       88
# 153            CM, CAM       D. van de Beek       83
# 186       CM, CAM, CDM             Paulinho       83
# 5557       CM, CAM, CF          José Machín       69
# 10530      CM, CAM, LB              K. Rowe       65
# 172        CM, CAM, LM       Renato Augusto       83
# 912        CM, CAM, LW        N. De la Cruz       77
# 18326      CM, CAM, RB            A. Taylor       52
# 575        CM, CAM, RM              Rafinha       79
# 6420       CM, CAM, RW             D. Olaru       68
# 2929       CM, CAM, ST          Juan Carlos       73
# 2157            CM, CB               Danilo       74
# 7966       CM, CB, CAM           C. Lepoint       67
# 3311       CM, CB, CDM       Cláudio Falcão       72
# 8392        CM, CB, RB         A. Rodriguez       67
# 49             CM, CDM             P. Pogba       86
# 70        CM, CDM, CAM  S. Milinković-Savić       85
# 1537       CM, CDM, CB          W. McKennie       75
# 3719       CM, CDM, LB           M. Benítez       72
# 798        CM, CDM, LM          A. Guardado       78
# 1921       CM, CDM, LW            S. Taïder       75
# 1074       CM, CDM, RB              S. Rudy       77
# 618        CM, CDM, RM           M. Sissoko       79
# 12644      CM, CDM, ST        B. Boulahroud       63
# 591             CM, CF       R. Malinovskyi       79
# 6042       CM, CF, CAM            K. Laribi       69
# 227         CM, CF, RM      Marcos Llorente       82
# 10299       CM, CF, ST             T. Arano       65
# 2779            CM, LB            G. Castro       73
# 3548        CM, LB, LM            O. Bayram       72
# 274             CM, LM             H. Aouar       81
# 983        CM, LM, CAM         Sergi Darder       77
# 17627       CM, LM, CB          Wu Shaocong       55
# 416        CM, LM, CDM              Campaña       80
# 112         CM, LM, LB                 Saúl       84
# 12418       CM, LM, LW           N. Freeman       63
# 9331        CM, LM, RB        C. Wernitznig       66
# 253         CM, LM, RM              Canales       82
# 4647        CM, LM, ST          T. Kunimoto       70
# 936             CM, LW        Óliver Torres       77
# 3382        CM, LW, LM           J. Ramírez       72
# 5006        CM, LW, ST          Yeom Ki Hun       70
# 2866           CM, LWB             P. Lasne       73
# 5716            CM, RB             G. Hamer       69
# 431         CM, RB, LB            J. Milner       80
# 11598       CM, RB, LM             R. Flynn       64
# 10605       CM, RB, RM              N. Yeri       65
# 1533            CM, RM     Gedson Fernandes       75
# 908        CM, RM, CAM          E. Palacios       77
# 698        CM, RM, CDM       Renato Sanches       78
# 96          CM, RM, LM                 Koke       85
# 10425       CM, RM, LW           M. Benítez       65
# 5235        CM, RM, RB            P. Faragò       70
# 3254        CM, RM, RW            D. Blanco       72
# 3338       CM, RM, RWB            A. Schöpf       72
# 4824            CM, RW          L. Blessing       70
# 1449       CM, RW, CAM           M. Pereyra       76
# 1721        CM, RW, LW            M. Moreno       75
# 17458       CM, RW, RM           Yao Hanlin       56
# 6136        CM, RW, ST                Dener       69
# 13360          CM, RWB        C. McGrandles       62
# 18618     CM, RWB, CDM             J. Yabur       51
# 10464           CM, ST           H. Hansson       65
# 10563      CM, ST, CDM             M. Osuna       65
# 2                   GK             J. Oblak       91
# 13817           GK, RB      Marlon Barninho       62
# 33                  LB         A. Robertson       87
# 6451           LB, CAM        Caio Henrique       68
# 558             LB, CB        R. Bensebaini       79
# 9956       LB, CB, CDM               B. Sam       65
# 800         LB, CB, LM          D. Criscito       78
# 267        LB, CB, LWB       M. Halstenberg       82
# 8104        LB, CB, RB        Yun Suk Young       67
# 3484           LB, CDM        N. Theuerkauf       72
# 8451       LB, CDM, CB              C. Mola       66
# 11786      LB, CDM, LM            E. Takeda       64
# 953             LB, CM        D. Sinkgraven       77
# 5860        LB, CM, LM          A. Escoboza       69
# 5752        LB, CM, LW          J. Medranda       69
# 2922        LB, CM, RB            S. Dallas       73
# 11111       LB, CM, ST              P. Ochs       64
# 95              LB, LM          Alex Sandro       85
# 1164       LB, LM, CAM        Andeson Trigo       77
# 2353        LB, LM, CB            L. Benito       74
# 12991       LB, LM, CM             A. Gallo       62
# 3609        LB, LM, LW            L. Krejčí       72
# 417        LB, LM, LWB            N. Schulz       80
# 1120        LB, LM, RB           L. Kurzawa       77
# 273         LB, LM, RM            A. Davies       81
# 6883            LB, LW          B. Vătăjelu       68
# 17015       LB, LW, CM          A. O'Hanlon       57
# 4532        LB, LW, LM          A. Bernabei       70
# 4675        LB, LW, RW                 Witi       70
# 334            LB, LWB        Marcos Alonso       81
# 2815       LB, LWB, CB        F. Kudryashov       73
# 10024     LB, LWB, CDM            Y. Sasman       65
# 16709      LB, LWB, CM             J. Evans       57
# 882        LB, LWB, LM           Gazzolisco       78
# 18733      LB, LWB, LW             R. Rydel       50
# 5659       LB, LWB, RB            G. Tigiev       69
# 852             LB, RB             J. Bořil       78
# 1161        LB, RB, CB        Enzo Chissano       77
# 4161       LB, RB, CDM          J. Trindade       71
# 9297        LB, RB, CM            A. Acosta       66
# 4529        LB, RB, LM               F. Agu       70
# 5629       LB, RB, LWB       Y. Vorogovskiy       69
# 2946        LB, RB, RM              E. Durm       73
# 11501       LB, RB, RW         Ahn Tae Hyun       64
# 2202       LB, RB, RWB            J. Brenet       74
# 7413            LB, RM           Kim Jin Ya       67
# 66                  LM              L. Sané       85
# 332            LM, CAM               Taison       81
# 7504      LM, CAM, CDM    A. Hadžiahmetović       67
# 2347       LM, CAM, CM             Y. Mallı       74
# 3191       LM, CAM, LB         L. Rodríguez       72
# 4409       LM, CAM, LW         V. Hernández       71
# 288        LM, CAM, RM             T. Lemar       81
# 5267       LM, CAM, ST          R. Dugimont       70
# 14218          LM, CDM               Thiago       61
# 9819       LM, CDM, RM          S. Milewski       65
# 46              LM, CF               H. Son       87
# 15145      LM, CF, CAM            T. Sasaki       60
# 2921        LM, CF, RM             O. Kragl       73
# 2736        LM, CF, ST            D. Terans       73
# 563             LM, CM            E. Bardhi       79
# 1556       LM, CM, CAM           S. Córdova       75
# 5349       LM, CM, CDM           B. Cáceres       70
# 1959        LM, CM, LB           P. Capelle       75
# 13787       LM, CM, LW              D. Mast       62
# 717         LM, CM, RM             M. Rojas       78
# 6360        LM, CM, RW        M. Pellegrini       68
# 275             LM, LB            Cucurella       81
# 18384       LM, LB, CB            T. Möller       52
# 9265       LM, LB, CDM              M. Gaus       66
# 15544       LM, LB, CF           S. Zehnder       59
# 116         LM, LB, CM         R. Guerreiro       84
# 3923        LM, LB, LW             M. Fares       71
# 5950       LM, LB, LWB             J. Hayes       69
# 1825        LM, LB, RB            Vieirinha       75
# 8201        LM, LB, RM           Y. Aguemon       67
# 247             LM, LW           I. Perišić       82
# 1577       LM, LW, CAM    A. Claude-Maurice       75
# 5530        LM, LW, CF           N. Barrios       69
# 13803       LM, LW, CM           Zhu Baojie       62
# 1339        LM, LW, LB          J. Gallardo       76
# 147         LM, LW, RM          S. Bergwijn       83
# 4223        LM, LW, RW           Yu Hanchao       71
# 373         LM, LW, ST     A. Saint-Maximin       80
# 206            LM, LWB            F. Kostić       83
# 9883       LM, LWB, CB           D. Sugioka       65
# 5764       LM, LWB, LB          G. Holtmann       69
# 13698      LM, LWB, RM        P. Malinowski       62
# 1500       LM, LWB, RW              B. Saka       75
# 12528      LM, LWB, ST          C. Hamilton       63
# 13652           LM, RB      Myeong Joon Jae       62
# 9481        LM, RB, CB           K. Shimizu       66
# 850         LM, RB, LB        L. Spinazzola       78
# 7367       LM, RB, RWB               Valery       67
# 208             LM, RM                 Rafa       83
# 1085       LM, RM, CAM            S. Blanco       77
# 11024       LM, RM, CB           A. Andrade       64
# 201         LM, RM, CF            T. Hazard       83
# 3003        LM, RM, CM           J. Meneses       73
# 6167        LM, RM, LB          C. Cisneros       69
# 108         LM, RM, LW             K. Coman       84
# 9439       LM, RM, LWB           Seo Bo Min       66
# 1025        LM, RM, RB             A. Young       77
# 1250        LM, RM, RW              S. Kalu       76
# 1325        LM, RM, ST          D. González       76
# 4767            LM, RW            R. Aarons       70
# 128         LM, RW, LW        Douglas Costa       84
# 5772        LM, RW, RM             L. Comas       69
# 3464       LM, RWB, RM     K. Monnet-Paquet       72
# 65              LM, ST          M. Rashford       85
# 659        LM, ST, CAM         Rubén García       79
# 4104        LM, ST, CF         K. Furuhashi       71
# 5318        LM, ST, CM          Borja Valle       70
# 5238        LM, ST, LB           B. Kololli       70
# 3647        LM, ST, LW            Cristiano       72
# 972         LM, ST, RM             M. Simon       77
# 6894        LM, ST, RW             A. Kanté       68
# 10                  LW              S. Mané       90
# 4              LW, CAM            Neymar Jr       91
# 2916       LW, CAM, CF          V. Eysseric       73
# 399        LW, CAM, CM          J. Grealish       80
# 7370       LW, CAM, LM             A. Mățan       67
# 12016      LW, CAM, RM     Víctor Fernández       63
# 190        LW, CAM, RW              Muniain       83
# 7489       LW, CAM, ST            J. Vargas       67
# 97              LW, CF           L. Insigne       85
# 1942        LW, CF, LM            G. Hauche       75
# 3079        LW, CF, RW           Pedro Neto       72
# 1039        LW, CF, ST              Matheus       77
# 656             LW, CM        H. Çalhanoğlu       79
# 7162            LW, LB          Fábio Nunes       68
# 12653       LW, LB, LM               A. Rey       63
# 452             LW, LM           A. Sánchez       80
# 1526       LW, LM, CAM            M. Vargas       75
# 1691        LW, LM, CF            F. Kamano       75
# 769         LW, LM, CM         Denis Suárez       78
# 2852        LW, LM, LB           J. Kovařík       73
# 6772        LW, LM, RM           B. Merlini       68
# 805         LW, LM, ST            I. Piatti       78
# 18736          LW, LWB         J. Carluccio       50
# 8241        LW, RM, CM        Jung Seok Hwa       67
# 15274       LW, RM, LM              R. Aoki       60
# 2576        LW, RM, RW           D. Vergara       73
# 19              LW, RW          R. Sterling       88
# 392        LW, RW, CAM          David Neres       80
# 739         LW, RW, CF       Daniel Podence       78
# 280         LW, RW, LM           C. Pulisic       81
# 1696        LW, RW, RM            Trezeguet       75
# 1029        LW, RW, ST             R. Babel       77
# 4307      LW, RWB, LWB            K. Harris       71
# 25              LW, ST            E. Hazard       88
# 5651       LW, ST, CAM              L. Boyé       69
# 374         LW, ST, CM           Diogo Jota       80
# 1916        LW, ST, LM               Juanmi       75
# 815         LW, ST, RW            L. Acosta       78
# 300                LWB                Jonny       81
# 3541           LWB, CB           Rúben Lima       72
# 2174           LWB, CM            B. Osborn       74
# 360            LWB, LB         Adryan Zonta       81
# 9394       LWB, LB, CB            K. Schulz       66
# 1007       LWB, LB, LM           J. Willems       77
# 1886           LWB, LM        G. Schennikov       75
# 5247       LWB, LM, CM       G. Þórarinsson       70
# 2640       LWB, LM, LB           M. Ullmann       73
# 5360       LWB, LM, RB           C. Rizzuto       70
# 4273       LWB, LM, RM        S. Hierländer       71
# 14943     LWB, LM, RWB            Y. Rafael       60
# 16874      LWB, LM, ST               J. Law       57
# 876            LWB, LW             Sequeira       78
# 1584       LWB, RM, LB              R. Skov       75
# 7991          LWB, RWB             N. Adams       67
# 29                  RB  T. Alexander-Arnold       87
# 13797          RB, CAM            Z. Kvržić       62
# 294             RB, CB            B. Pavard       81
# 1622       RB, CB, CDM             D. Muñoz       75
# 3238        RB, CB, LB            A. Vallci       72
# 7070        RB, CB, RM             L. Marín       68
# 368        RB, CB, RWB           N. Mukiele       80
# 15416       RB, CB, ST          Lee Tae Hee       60
# 911            RB, CDM             R. James       77
# 244        RB, CDM, CM            L. Bender       82
# 15933      RB, CDM, LB          T. Abdullah       59
# 7494       RB, CDM, RM           J. Ryerson       67
# 197             RB, CM        Sergi Roberto       83
# 5224       RB, CM, CAM            B. Saller       70
# 9734        RB, CM, CB           T. Sibbick       65
# 16797      RB, CM, CDM        G. Mukumbilwa       57
# 8478        RB, CM, LB            P. Maslov       66
# 3095        RB, CM, RM              R. Baku       72
# 4924       RB, CM, RWB             J. Gómez       70
# 127             RB, LB          Azpilicueta       84
# 1116        RB, LB, CB        D. D'Ambrosio       77
# 11375      RB, LB, CDM        Park Yi-Young       64
# 7258        RB, LB, CM            M. Mihara       68
# 9078       RB, LB, LWB            E. Miller       66
# 1261        RB, LB, RM          B. Henrichs       76
# 2901       RB, LB, RWB             A. Bamba       73
# 13239           RB, LM            M. Diallo       62
# 5402        RB, LM, LB          J. Vagnoman       69
# 14940          RB, LWB             D. Sesay       60
# 121             RB, RM          Jesús Navas       84
# 8980       RB, RM, CAM       M. Gottschling       66
# 5816        RB, RM, CB             O. Bosso       69
# 8422       RB, RM, CDM          K. Kitazume       67
# 442         RB, RM, CM              D. Wass       80
# 1262        RB, RM, LB              William       76
# 4060        RB, RM, LM                 Nanu       71
# 335         RB, RM, RW          J. Cuadrado       81
# 686        RB, RM, RWB              Emerson       78
# 13900       RB, RM, ST        Tiago Almeida       61
# 523             RB, RW              Y. Atal       79
# 2246        RB, RW, LB                Lekue       74
# 149            RB, RWB       A. Wan-Bissaka       83
# 2858       RB, RWB, CB         H. Dalsgaard       73
# 10528     RB, RWB, CDM           E. Dudouit       65
# 10353      RB, RWB, CM         J. Demetriou       65
# 3141       RB, RWB, LB             M. Wagué       72
# 11122     RB, RWB, LWB           M. Godinho       64
# 1224       RB, RWB, RM         Aurélio Buta       76
# 5533       RB, RWB, RW          J. Bataille       69
# 15214       RB, ST, CB       N. Billingsley       60
# 11530       RB, ST, LM             A. Askar       64
# 150                 RM            A. Hakimi       83
# 331            RM, CAM               Marlos       81
# 5038       RM, CAM, CF           N. De Pauw       70
# 403        RM, CAM, CM               Otávio       80
# 1996       RM, CAM, LM            J. Lolley       75
# 4378       RM, CAM, RB            J. Botaka       71
# 470        RM, CAM, RW        H. Mkhitaryan       80
# 2165       RM, CAM, ST           M. Okugawa       74
# 11808          RM, CDM             R. Aabid       64
# 8013       RM, CDM, LM           R. Boguski       67
# 200             RM, CF          Lucas Moura       83
# 5910       RM, CF, CAM           N. Dovedan       69
# 2822        RM, CF, LM           F. Bartels       73
# 9153        RM, CF, RB          O. Arellano       66
# 7875        RM, CF, ST             N. Maeda       67
# 134             RM, CM                Pizzi       84
# 1070       RM, CM, CAM              Rochina       77
# 7785       RM, CM, CDM              A. Polo       67
# 5612        RM, CM, LM           A. Hrustić       69
# 2997        RM, CM, RB           W. Montoya       73
# 4235        RM, CM, ST            Go Yo Han       71
# 12465       RM, LB, CM             M. Maier       63
# 1891        RM, LB, RB              A. Nyom       75
# 584             RM, LM      Samu Castillejo       79
# 28         RM, LM, CAM            J. Sancho       87
# 16586       RM, LM, CB              Yang Yu       58
# 9503       RM, LM, CDM              V. Peña       66
# 276         RM, LM, CF        Ferran Torres       81
# 535         RM, LM, CM         Carlos Soler       79
# 2443        RM, LM, LB           O. Şahiner       74
# 8083        RM, LM, LW             C. Noone       67
# 10208      RM, LM, LWB              O. Myny       65
# 4087        RM, LM, RB         F. Mattiello       71
# 76          RM, LM, RW            S. Gnabry       85
# 1438       RM, LM, RWB           J. Forrest       76
# 915         RM, LM, ST            K. Diatta       77
# 2859            RM, LW          I. Brizuela       73
# 4359       RM, LW, CAM            E. Başsan       71
# 4456        RM, LW, RW              Amilton       71
# 8630        RM, LW, ST             F. Reese       66
# 1064           RM, LWB           M. Ritchie       77
# 130             RM, RB            J. Corona       84
# 8820       RM, RB, CAM             B. Barry       66
# 2290        RM, RB, LB             N. Dirar       74
# 6061        RM, RB, LM            T. Schick       69
# 8483        RM, RB, RW         J. Osei-Tutu       66
# 5537       RM, RB, RWB                 Pipa       69
# 226             RM, RW              N. Pépé       82
# 622        RM, RW, CAM          S. Feghouli       79
# 1969        RM, RW, CF             F. Pardo       75
# 2111        RM, RW, CM            O. Pineda       74
# 1595        RM, RW, LM             S. Villa       75
# 3407        RM, RW, LW          J. Menéndez       72
# 8204        RM, RW, RB            N. DeLeon       67
# 357         RM, RW, ST          M. Politano       81
# 799            RM, RWB             V. Moses       78
# 2252      RM, RWB, CAM           J. Gressel       74
# 8311       RM, RWB, LM            M. Ibarra       67
# 544        RM, RWB, RB            V. Lazaro       79
# 7167       RM, RWB, ST             M. Boyle       68
# 224             RM, ST            A. Correa       82
# 1149       RM, ST, CAM             Y. Chará       77
# 10288       RM, ST, CF         S. Kobayashi       65
# 18290       RM, ST, CM           Xie Weijun       53
# 931         RM, ST, LM         D. Lukébakio       77
# 1418        RM, ST, RW           R. Hamouma       76
# 11                  RW             M. Salah       90
# 341            RW, CAM        Pablo Sarabia       81
# 34         RW, CAM, CM       Bernardo Silva       87
# 10825      RW, CAM, LM       T. Maciejewski       64
# 3124       RW, CAM, LW      A. Saelemaekers       72
# 3950       RW, CAM, RM             J. Byrne       71
# 3032            RW, CF         Fabri Arnoia       73
# 8574       RW, CF, CAM             S. Edera       66
# 6480        RW, CF, LW          D. Saggiomo       68
# 3915            RW, CM           M. Bolados       71
# 4046       RW, CM, CAM            A. Traoré       71
# 2931            RW, LB         L. Melgarejo       73
# 10162           RW, LM             C. Souza       65
# 3872        RW, LM, LW             B. Jatta       71
# 12763       RW, LM, ST        O. Gaona Lugo       63
# 39              RW, LW          A. Di María       87
# 173        RW, LW, CAM              C. Vela       83
# 1961        RW, LW, CF           Fei Nanduo       75
# 1144        RW, LW, LM         R. Centurión       77
# 10705       RW, LW, RB            Zé Uilton       65
# 246         RW, LW, RM              Willian       82
# 4673       RW, LW, RWB          Sergi Canós       70
# 4234        RW, LW, ST             G. Bruno       71
# 1603       RW, LWB, LW            M. Cornet       75
# 4135       RW, LWB, RM    I. Tajouri-Shradi       71
# 3792            RW, RB            J. Clauss       72
# 11923       RW, RB, LB   J. Rankin-Costello       63
# 14887       RW, RB, LW            B. Dedola       60
# 1108        RW, RB, RM        J. Fuenzalida       77
# 98              RW, RM            R. Mahrez       85
# 3070       RW, RM, CAM         S. Rodríguez       72
# 202         RW, RM, CF                Portu       83
# 9196        RW, RM, LM           Zheng Long       66
# 2485        RW, RM, LW           J. Kayamba       74
# 5528        RW, RM, ST          O. Okwonkwo       69
# 518            RW, RWB         Adama Traoré       79
# 459             RW, ST                 Hulk       80
# 3080       RW, ST, CAM             A. Olsen       72
# 0           RW, ST, CF             L. Messi       93
# 407         RW, ST, LW            H. Lozano       80
# 3398        RW, ST, RM          A. González       72
# 1001               RWB           G. Baldock       77
# 13695         RWB, CAM              R. Finn       62
# 7702          RWB, CDM         Tiago Esgaio       67
# 8106           RWB, CM           J. Edwards       67
# 10405      RWB, CM, RM          S. Wagstaff       65
# 14118          RWB, LM             S. Delos       61
# 9995          RWB, LWB              P. Dorn       65
# 347            RWB, RB           M. Doherty       81
# 7611       RWB, RB, CB           J. Dacosta       67
# 652        RWB, RB, LB              K. Lala       79
# 1275      RWB, RB, LWB            Manquillo       76
# 481        RWB, RB, RM         P. Kadeřábek       80
# 255            RWB, RM      Mário Fernandes       82
# 18398      RWB, RM, LM         D. Jovanović       52
# 4900      RWB, RM, LWB          N. Lavanchy       70
# 768        RWB, RM, RB          D. da Costa       78
# 775            RWB, RW       Ricardo Esgaio       78
# 15671          RWB, ST             A. Bruus       59
# 3                   ST       R. Lewandowski       91
# 268            ST, CAM          A. Kramarić       82
# 787        ST, CAM, CF             C. Tévez       78
# 4302       ST, CAM, CM           A. Weimann       71
# 2103       ST, CAM, LM         Manu Vallejo       74
# 5014       ST, CAM, LW        F. Forestieri       70
# 3244       ST, CAM, RM           T. Fountas       72
# 441        ST, CAM, RW          Raúl García       80
# 12850           ST, CB           O. Hawkins       63
# 12576      ST, CB, CDM       D. Gravenberch       63
# 13576       ST, CB, RB        Park Dong Jin       62
# 318             ST, CF            A. Gignac       81
# 901        ST, CF, CAM             J. David       77
# 2690        ST, CF, LM           K. Karaman       73
# 45          ST, CF, LW         A. Griezmann       87
# 14017       ST, CF, RM          L. Sandoval       61
# 6361        ST, CF, RW            A. Kutucu       68
# 8176            ST, CM      M. Vilhjálmsson       67
# 2592       ST, CM, CAM        S. Schrijvers       73
# 8342        ST, CM, RB       Nazarinho Rios       67
# 353             ST, LM            E. Zahavi       81
# 1324       ST, LM, CAM           R. Quaison       76
# 10993       ST, LM, CF        L. Lauberbach       64
# 1284        ST, LM, LW             K. Baldé       76
# 4128        ST, LM, RB            R. Ripart       71
# 666         ST, LM, RM              Morales       79
# 1991        ST, LM, RW            A. Romero       75
# 1               ST, LW    Cristiano Ronaldo       92
# 628        ST, LW, CAM        Alex Teixeira       79
# 5782        ST, LW, CF     Carlinhos Junior       69
# 12226       ST, LW, CM       Cho Young Wook       63
# 1069        ST, LW, LM        Alan Carvalho       77
# 10203      ST, LW, LWB            S. Skrabb       65
# 17449       ST, LW, RM          Chang Feiya       56
# 6           ST, LW, RW            K. Mbappé       90
# 13845           ST, RB          R. Frantsen       62
# 10368       ST, RB, RM             L. Akins       65
# 561             ST, RM             E. Ávila       79
# 2099       ST, RM, CAM         J. Hernández       74
# 205         ST, RM, CF        Gerard Moreno       83
# 277         ST, RM, LM          Richarlison       81
# 2179        ST, RM, LW             I. Bebou       74
# 2669        ST, RM, RW          C. Bassogog       73
# 7571       ST, RM, RWB         Aitor Ruibal       67
# 129             ST, RW           Iago Aspas       84
# 2934       ST, RW, CAM       Diego Oliveira       73
# 12874       ST, RW, CF              G. Páez       63
# 9885        ST, RW, LM         A. Rodríguez       65
# 345         ST, RW, LW           K. Volland       81
# 858         ST, RW, RM        Leo Baptistao       78
# 13680          ST, RWB             B. Moore       62

# %% [markdown]
# Conteos por posiciones

# %%
pd.DataFrame(df.player_positions.value_counts().sort_index())
# Out:
#               player_positions
# CAM                        268
# CAM, CDM                    13
# CAM, CDM, CM                 4
# CAM, CDM, LM                 1
# CAM, CF                     23
# CAM, CF, CM                  8
# CAM, CF, LM                  1
# CAM, CF, RM                  3
# CAM, CF, RW                  2
# CAM, CF, ST                 11
# CAM, CM                    228
# CAM, CM, CDM                15
# CAM, CM, CF                  8
# CAM, CM, LM                 29
# CAM, CM, LW                 13
# CAM, CM, RM                 25
# CAM, CM, RW                  5
# CAM, CM, ST                  9
# CAM, LB                      1
# CAM, LM                     75
# CAM, LM, CF                  2
# CAM, LM, CM                 16
# CAM, LM, LB                  2
# CAM, LM, LW                  7
# CAM, LM, RM                 24
# CAM, LM, RW                  1
# CAM, LM, ST                 10
# CAM, LW                     23
# CAM, LW, CF                  1
# CAM, LW, CM                  4
# CAM, LW, RW                  6
# CAM, LW, ST                  3
# CAM, RB                      2
# CAM, RM                     91
# CAM, RM, CF                  4
# CAM, RM, CM                 14
# CAM, RM, LM                 26
# CAM, RM, LW                  1
# CAM, RM, RB                  2
# CAM, RM, RW                  5
# CAM, RM, ST                 11
# CAM, RW                     30
# CAM, RW, CF                  1
# CAM, RW, CM                  2
# CAM, RW, LW                  7
# CAM, RW, RM                  4
# CAM, RW, ST                  4
# CAM, RWB, CM                 1
# CAM, ST                     61
# CAM, ST, CF                  5
# CAM, ST, CM                  9
# CAM, ST, LM                  9
# CAM, ST, LW                  7
# CAM, ST, RM                  5
# CAM, ST, RW                  6
# CB                        2437
# CB, CAM                      1
# CB, CAM, CM                  1
# CB, CDM                    209
# CB, CDM, CM                 22
# CB, CDM, LB                  6
# CB, CDM, RB                 11
# CB, CDM, RM                  1
# CB, CM                      13
# CB, CM, CDM                  5
# CB, LB                     212
# CB, LB, CDM                  3
# CB, LB, LWB                  5
# CB, LB, RB                  12
# CB, LM                       1
# CB, LWB                      9
# CB, RB                     236
# CB, RB, CDM                 15
# CB, RB, CM                   2
# CB, RB, LB                  21
# CB, RB, RM                   2
# CB, RB, RWB                  2
# CB, RB, ST                   1
# CB, RM                       1
# CB, RM, RB                   1
# CB, RW                       1
# CB, RWB                     14
# CB, RWB, RB                  2
# CB, RWB, RM                  1
# CB, ST                       4
# CB, ST, CAM                  1
# CDM                        349
# CDM, CAM                    12
# CDM, CAM, CM                 5
# CDM, CAM, LM                 1
# CDM, CB                     99
# CDM, CB, CM                 25
# CDM, CB, LB                  1
# CDM, CB, RB                  4
# CDM, CB, RM                  1
# CDM, CM                    827
# CDM, CM, CAM                29
# CDM, CM, CB                 53
# CDM, CM, LB                  8
# CDM, CM, LM                  4
# CDM, CM, RB                 14
# CDM, CM, RM                 14
# CDM, CM, RWB                 1
# CDM, LB                     11
# CDM, LB, CB                  1
# CDM, LB, CM                  1
# CDM, LM                      3
# CDM, LM, CM                  1
# CDM, RB                     26
# CDM, RB, CB                  4
# CDM, RB, CM                  8
# CDM, RB, LB                  2
# CDM, RB, RM                  3
# CDM, RM                      2
# CDM, RM, CM                  1
# CDM, RM, RB                  1
# CDM, RW, RB                  1
# CDM, RWB                     1
# CDM, ST                      1
# CF                          15
# CF, CAM                     13
# CF, CAM, CM                  3
# CF, CAM, LM                  2
# CF, CAM, LW                  5
# CF, CAM, RW                  1
# CF, CAM, ST                  5
# CF, CM                       4
# CF, CM, LM                   1
# CF, LM                       2
# CF, LM, CAM                  1
# CF, LM, LW                   1
# CF, LM, RM                   1
# CF, LW                       3
# CF, LW, CAM                  2
# CF, LW, RW                   1
# CF, LW, ST                   2
# CF, RM                       3
# CF, RM, CM                   1
# CF, RM, RW                   1
# CF, RM, RWB                  1
# CF, RM, ST                   1
# CF, RW                       2
# CF, ST                      32
# CF, ST, CAM                  4
# CF, ST, CM                   1
# CF, ST, LM                   3
# CF, ST, LW                   2
# CF, ST, RM                   1
# CF, ST, RW                   1
# CM                         810
# CM, CAM                    211
# CM, CAM, CDM                57
# CM, CAM, CF                  2
# CM, CAM, LB                  1
# CM, CAM, LM                 15
# CM, CAM, LW                  7
# CM, CAM, RB                  2
# CM, CAM, RM                 19
# CM, CAM, RW                  6
# CM, CAM, ST                  2
# CM, CB                      12
# CM, CB, CAM                  1
# CM, CB, CDM                  6
# CM, CB, RB                   1
# CM, CDM                    693
# CM, CDM, CAM                79
# CM, CDM, CB                 16
# CM, CDM, LB                  4
# CM, CDM, LM                  9
# CM, CDM, LW                  1
# CM, CDM, RB                 10
# CM, CDM, RM                 17
# CM, CDM, ST                  1
# CM, CF                       6
# CM, CF, CAM                  1
# CM, CF, RM                   2
# CM, CF, ST                   1
# CM, LB                       8
# CM, LB, LM                   2
# CM, LM                      51
# CM, LM, CAM                  4
# CM, LM, CB                   1
# CM, LM, CDM                  5
# CM, LM, LB                   5
# CM, LM, LW                   1
# CM, LM, RB                   1
# CM, LM, RM                  12
# CM, LM, ST                   1
# CM, LW                       5
# CM, LW, LM                   1
# CM, LW, ST                   1
# CM, LWB                      3
# CM, RB                      21
# CM, RB, LB                   2
# CM, RB, LM                   1
# CM, RB, RM                   5
# CM, RM                      48
# CM, RM, CAM                 10
# CM, RM, CDM                 12
# CM, RM, LM                  13
# CM, RM, LW                   1
# CM, RM, RB                   4
# CM, RM, RW                   1
# CM, RM, RWB                  1
# CM, RW                      12
# CM, RW, CAM                  1
# CM, RW, LW                   5
# CM, RW, RM                   1
# CM, RW, ST                   1
# CM, RWB                      3
# CM, RWB, CDM                 1
# CM, ST                       4
# CM, ST, CDM                  1
# GK                        2083
# GK, RB                       1
# LB                         770
# LB, CAM                      1
# LB, CB                     109
# LB, CB, CDM                  2
# LB, CB, LM                   7
# LB, CB, LWB                  5
# LB, CB, RB                   5
# LB, CDM                     13
# LB, CDM, CB                  2
# LB, CDM, LM                  1
# LB, CM                      11
# LB, CM, LM                   1
# LB, CM, LW                   1
# LB, CM, RB                   1
# LB, CM, ST                   2
# LB, LM                     181
# LB, LM, CAM                  2
# LB, LM, CB                   7
# LB, LM, CM                   2
# LB, LM, LW                   3
# LB, LM, LWB                  8
# LB, LM, RB                   6
# LB, LM, RM                   6
# LB, LW                       7
# LB, LW, CM                   1
# LB, LW, LM                   1
# LB, LW, RW                   2
# LB, LWB                    110
# LB, LWB, CB                  4
# LB, LWB, CDM                 1
# LB, LWB, CM                  2
# LB, LWB, LM                 40
# LB, LWB, LW                  1
# LB, LWB, RB                  3
# LB, RB                      55
# LB, RB, CB                  10
# LB, RB, CDM                  2
# LB, RB, CM                   2
# LB, RB, LM                   1
# LB, RB, LWB                  2
# LB, RB, RM                   7
# LB, RB, RW                   1
# LB, RB, RWB                  1
# LB, RM                       3
# LM                         262
# LM, CAM                     62
# LM, CAM, CDM                 1
# LM, CAM, CM                 10
# LM, CAM, LB                  3
# LM, CAM, LW                  2
# LM, CAM, RM                 16
# LM, CAM, ST                  9
# LM, CDM                      3
# LM, CDM, RM                  1
# LM, CF                       8
# LM, CF, CAM                  1
# LM, CF, RM                   3
# LM, CF, ST                   4
# LM, CM                      29
# LM, CM, CAM                  7
# LM, CM, CDM                  2
# LM, CM, LB                   5
# LM, CM, LW                   1
# LM, CM, RM                   4
# LM, CM, RW                   2
# LM, LB                      44
# LM, LB, CB                   1
# LM, LB, CDM                  1
# LM, LB, CF                   1
# LM, LB, CM                   3
# LM, LB, LW                   2
# LM, LB, LWB                  2
# LM, LB, RB                   3
# LM, LB, RM                   3
# LM, LW                      63
# LM, LW, CAM                  6
# LM, LW, CF                   1
# LM, LW, CM                   2
# LM, LW, LB                   2
# LM, LW, RM                  17
# LM, LW, RW                   5
# LM, LW, ST                  13
# LM, LWB                     11
# LM, LWB, CB                  1
# LM, LWB, LB                  2
# LM, LWB, RM                  1
# LM, LWB, RW                  1
# LM, LWB, ST                  1
# LM, RB                       1
# LM, RB, CB                   1
# LM, RB, LB                   1
# LM, RB, RWB                  1
# LM, RM                     223
# LM, RM, CAM                 26
# LM, RM, CB                   2
# LM, RM, CF                   1
# LM, RM, CM                  10
# LM, RM, LB                   1
# LM, RM, LW                  11
# LM, RM, LWB                  2
# LM, RM, RB                   7
# LM, RM, RW                   8
# LM, RM, ST                  31
# LM, RW                       3
# LM, RW, LW                   1
# LM, RW, RM                   3
# LM, RWB, RM                  1
# LM, ST                      73
# LM, ST, CAM                  6
# LM, ST, CF                   1
# LM, ST, CM                   1
# LM, ST, LB                   2
# LM, ST, LW                   5
# LM, ST, RM                  24
# LM, ST, RW                   2
# LW                         113
# LW, CAM                     18
# LW, CAM, CF                  2
# LW, CAM, CM                  2
# LW, CAM, LM                  2
# LW, CAM, RM                  1
# LW, CAM, RW                  2
# LW, CAM, ST                  2
# LW, CF                       7
# LW, CF, LM                   1
# LW, CF, RW                   2
# LW, CF, ST                   1
# LW, CM                       2
# LW, LB                       3
# LW, LB, LM                   2
# LW, LM                      40
# LW, LM, CAM                  6
# LW, LM, CF                   2
# LW, LM, CM                   2
# LW, LM, LB                   3
# LW, LM, RM                   2
# LW, LM, ST                   7
# LW, LWB                      1
# LW, RM, CM                   1
# LW, RM, LM                   1
# LW, RM, RW                   1
# LW, RW                      98
# LW, RW, CAM                 14
# LW, RW, CF                   8
# LW, RW, LM                   8
# LW, RW, RM                   2
# LW, RW, ST                  13
# LW, RWB, LWB                 1
# LW, ST                      33
# LW, ST, CAM                  1
# LW, ST, CM                   1
# LW, ST, LM                   5
# LW, ST, RW                  10
# LWB                         23
# LWB, CB                      6
# LWB, CM                      3
# LWB, LB                     39
# LWB, LB, CB                  2
# LWB, LB, LM                  4
# LWB, LM                      9
# LWB, LM, CM                  1
# LWB, LM, LB                  3
# LWB, LM, RB                  1
# LWB, LM, RM                  1
# LWB, LM, RWB                 1
# LWB, LM, ST                  1
# LWB, LW                      3
# LWB, RM, LB                  1
# LWB, RWB                     2
# RB                         656
# RB, CAM                      2
# RB, CB                     124
# RB, CB, CDM                  7
# RB, CB, LB                  11
# RB, CB, RM                   4
# RB, CB, RWB                 11
# RB, CB, ST                   1
# RB, CDM                     25
# RB, CDM, CM                  6
# RB, CDM, LB                  1
# RB, CDM, RM                  2
# RB, CM                      12
# RB, CM, CAM                  1
# RB, CM, CB                   1
# RB, CM, CDM                  1
# RB, CM, LB                   2
# RB, CM, RM                   3
# RB, CM, RWB                  1
# RB, LB                     133
# RB, LB, CB                   9
# RB, LB, CDM                  2
# RB, LB, CM                   1
# RB, LB, LWB                  1
# RB, LB, RM                   6
# RB, LB, RWB                  7
# RB, LM                       3
# RB, LM, LB                   1
# RB, LWB                      1
# RB, RM                     122
# RB, RM, CAM                  1
# RB, RM, CB                   3
# RB, RM, CDM                  2
# RB, RM, CM                   7
# RB, RM, LB                  10
# RB, RM, LM                   2
# RB, RM, RW                   7
# RB, RM, RWB                 12
# RB, RM, ST                   2
# RB, RW                      11
# RB, RW, LB                   1
# RB, RWB                     97
# RB, RWB, CB                  6
# RB, RWB, CDM                 2
# RB, RWB, CM                  2
# RB, RWB, LB                  8
# RB, RWB, LWB                 1
# RB, RWB, RM                 28
# RB, RWB, RW                  2
# RB, ST, CB                   1
# RB, ST, LM                   1
# RM                         269
# RM, CAM                     54
# RM, CAM, CF                  2
# RM, CAM, CM                  8
# RM, CAM, LM                 11
# RM, CAM, RB                  1
# RM, CAM, RW                  1
# RM, CAM, ST                  4
# RM, CDM                      4
# RM, CDM, LM                  1
# RM, CF                       4
# RM, CF, CAM                  3
# RM, CF, LM                   1
# RM, CF, RB                   1
# RM, CF, ST                   1
# RM, CM                      35
# RM, CM, CAM                 10
# RM, CM, CDM                  2
# RM, CM, LM                   4
# RM, CM, RB                   3
# RM, CM, ST                   5
# RM, LB, CM                   1
# RM, LB, RB                   2
# RM, LM                     201
# RM, LM, CAM                 33
# RM, LM, CB                   1
# RM, LM, CDM                  1
# RM, LM, CF                   6
# RM, LM, CM                  20
# RM, LM, LB                   5
# RM, LM, LW                   3
# RM, LM, LWB                  3
# RM, LM, RB                   7
# RM, LM, RW                  11
# RM, LM, RWB                  1
# RM, LM, ST                  37
# RM, LW                       5
# RM, LW, CAM                  1
# RM, LW, RW                   2
# RM, LW, ST                   2
# RM, LWB                      1
# RM, RB                      48
# RM, RB, CAM                  2
# RM, RB, LB                   3
# RM, RB, LM                   3
# RM, RB, RW                   2
# RM, RB, RWB                  2
# RM, RW                      72
# RM, RW, CAM                  5
# RM, RW, CF                   4
# RM, RW, CM                   6
# RM, RW, LM                  11
# RM, RW, LW                   4
# RM, RW, RB                   1
# RM, RW, ST                  13
# RM, RWB                     12
# RM, RWB, CAM                 1
# RM, RWB, LM                  2
# RM, RWB, RB                  4
# RM, RWB, ST                  1
# RM, ST                      63
# RM, ST, CAM                  7
# RM, ST, CF                   1
# RM, ST, CM                   1
# RM, ST, LM                  25
# RM, ST, RW                   5
# RW                         120
# RW, CAM                     26
# RW, CAM, CM                  1
# RW, CAM, LM                  1
# RW, CAM, LW                  3
# RW, CAM, RM                  2
# RW, CF                       5
# RW, CF, CAM                  1
# RW, CF, LW                   1
# RW, CM                       8
# RW, CM, CAM                  1
# RW, LB                       1
# RW, LM                       5
# RW, LM, LW                   1
# RW, LM, ST                   1
# RW, LW                      92
# RW, LW, CAM                 10
# RW, LW, CF                   3
# RW, LW, LM                   2
# RW, LW, RB                   1
# RW, LW, RM                  14
# RW, LW, RWB                  1
# RW, LW, ST                  17
# RW, LWB, LW                  1
# RW, LWB, RM                  1
# RW, RB                       6
# RW, RB, LB                   1
# RW, RB, LW                   1
# RW, RB, RM                   1
# RW, RM                      40
# RW, RM, CAM                  3
# RW, RM, CF                   1
# RW, RM, LM                   1
# RW, RM, LW                   4
# RW, RM, ST                   2
# RW, RWB                      3
# RW, ST                      40
# RW, ST, CAM                  3
# RW, ST, CF                   3
# RW, ST, LW                   9
# RW, ST, RM                   1
# RWB                         12
# RWB, CAM                     1
# RWB, CDM                     2
# RWB, CM                      4
# RWB, CM, RM                  1
# RWB, LM                      1
# RWB, LWB                     5
# RWB, RB                     30
# RWB, RB, CB                  2
# RWB, RB, LB                  1
# RWB, RB, LWB                 2
# RWB, RB, RM                  3
# RWB, RM                     11
# RWB, RM, LM                  1
# RWB, RM, LWB                 2
# RWB, RM, RB                  5
# RWB, RW                      4
# RWB, ST                      1
# ST                        1893
# ST, CAM                     84
# ST, CAM, CF                  6
# ST, CAM, CM                  5
# ST, CAM, LM                 14
# ST, CAM, LW                  3
# ST, CAM, RM                  4
# ST, CAM, RW                  3
# ST, CB                       1
# ST, CB, CDM                  1
# ST, CB, RB                   1
# ST, CF                      56
# ST, CF, CAM                  9
# ST, CF, LM                   4
# ST, CF, LW                   7
# ST, CF, RM                   1
# ST, CF, RW                   5
# ST, CM                       3
# ST, CM, CAM                  2
# ST, CM, RB                   1
# ST, LM                      80
# ST, LM, CAM                  9
# ST, LM, CF                   1
# ST, LM, LW                   9
# ST, LM, RB                   1
# ST, LM, RM                  25
# ST, LM, RW                   2
# ST, LW                      87
# ST, LW, CAM                  8
# ST, LW, CF                   2
# ST, LW, CM                   1
# ST, LW, LM                   6
# ST, LW, LWB                  1
# ST, LW, RM                   1
# ST, LW, RW                  25
# ST, RB                       1
# ST, RB, RM                   1
# ST, RM                      89
# ST, RM, CAM                  7
# ST, RM, CF                   1
# ST, RM, LM                  34
# ST, RM, LW                   3
# ST, RM, RW                   4
# ST, RM, RWB                  2
# ST, RW                      84
# ST, RW, CAM                  5
# ST, RW, CF                   1
# ST, RW, LM                   2
# ST, RW, LW                  43
# ST, RW, RM                   5
# ST, RWB                      2

# %%
club_avg_overall=df.groupby("club_name")["overall"].mean().reset_index().sort_values("overall",ascending=False)
club_avg_overall.head(8)
# Out:
#              club_name    overall
# 216  FC Bayern München  81.045455
# 489        Real Madrid  79.250000
# 131            Chelsea  79.212121
# 214       FC Barcelona  78.909091
# 374          Liverpool  78.575758
# 330              Inter  78.000000
# 387  Manchester United  77.818182
# 386    Manchester City  77.484848

# %% [markdown]
# ## 2.-Preparación-de-los-datos

# %% [markdown]
# **Retiramos jugadores con bajo Desempeño global ("Overall"), reducimos el tamaño de la base**
#
# **y consideramos Variables de desempeño por habilidad (skills_ratings)**

# %%
n=10000 #cantidad de jugadores a considerar

df_n=df.loc[:n] #se reduce la base a los n primeros jugadores

df_n=df_n[(df_n['overall']>70)]

skills_ratings = ['attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing',
                  'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
                  'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions',
                  'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
                  'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 
                  'mentality_composure', 'defending_marking', 'defending_standing_tackle', 'defending_sliding_tackle',
                  'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes']
print(len(skills_ratings), 'variables numéricas de desempeño según habilidad')
# Out:
# 34 variables numéricas de desempeño según habilidad

# %% [markdown]
# **Se crea el jugador perfecto para ver a donde se ubica en nuestra visualización**

# %%
MachineGunDict={'short_name':'MachineGun','overall':99}
for skills in skills_ratings:
    MachineGunDict[skills]=99
    
df_n=df_n.append(MachineGunDict,ignore_index=True)

# %%
df_skills=df_n[skills_ratings] #base, sólo con desempeños según habilidad (numéricas)

# %%
df_skills.head(4)
# Out:
#    attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 0                  85                   95                          70
# 1                  84                   95                          90
# 2                  13                   11                          15
# 3                  71                   94                          85
#
#    attacking_short_passing  attacking_volleys  skill_dribbling  skill_curve  \
# 0                       91                 88               96           93
# 1                       82                 86               88           81
# 2                       43                 13               12           13
# 3                       84                 89               85           79
#
#    skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 0                 94                  91                  96
# 1                 76                  77                  92
# 2                 14                  40                  30
# 3                 85                  70                  88
#
#    movement_acceleration  movement_sprint_speed  movement_agility  \
# 0                     91                     80                91
# 1                     87                     91                87
# 2                     43                     60                67
# 3                     77                     78                77
#
#    movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 0                  94                95                86             68
# 1                  95                71                94             95
# 2                  88                49                59             78
# 3                  93                82                89             84
#
#    power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 0             72              69                94                    44
# 1             84              78                93                    63
# 2             41              78                12                    34
# 3             76              86                85                    81
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       40                     93                95
# 1                       29                     95                82
# 2                       19                     11                65
# 3                       49                     94                79
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                NaN
# 1                   84                   95                NaN
# 2                   11                   68                NaN
# 3                   88                   88                NaN
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         35                        24                   6
# 1                         32                        24                   7
# 2                         12                        18                  87
# 3                         42                        19                  15
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                    11                   15                       14
# 1                    11                   15                       14
# 2                    92                   78                       90
# 3                     6                   12                        8
#
#    goalkeeping_reflexes
# 0                     8
# 1                    11
# 2                    90
# 3                    10

# %%
df_skills.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4513 entries, 0 to 4512
# Data columns (total 34 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   attacking_crossing          4513 non-null   int64
#  1   attacking_finishing         4513 non-null   int64
#  2   attacking_heading_accuracy  4513 non-null   int64
#  3   attacking_short_passing     4513 non-null   int64
#  4   attacking_volleys           4513 non-null   int64
#  5   skill_dribbling             4513 non-null   int64
#  6   skill_curve                 4513 non-null   int64
#  7   skill_fk_accuracy           4513 non-null   int64
#  8   skill_long_passing          4513 non-null   int64
#  9   skill_ball_control          4513 non-null   int64
#  10  movement_acceleration       4513 non-null   int64
#  11  movement_sprint_speed       4513 non-null   int64
#  12  movement_agility            4513 non-null   int64
#  13  movement_reactions          4513 non-null   int64
#  14  movement_balance            4513 non-null   int64
#  15  power_shot_power            4513 non-null   int64
#  16  power_jumping               4513 non-null   int64
#  17  power_stamina               4513 non-null   int64
#  18  power_strength              4513 non-null   int64
#  19  power_long_shots            4513 non-null   int64
#  20  mentality_aggression        4513 non-null   int64
#  21  mentality_interceptions     4513 non-null   int64
#  22  mentality_positioning       4513 non-null   int64
#  23  mentality_vision            4513 non-null   int64
#  24  mentality_penalties         4513 non-null   int64
#  25  mentality_composure         4513 non-null   int64
#  26  defending_marking           1 non-null      float64
#  27  defending_standing_tackle   4513 non-null   int64
#  28  defending_sliding_tackle    4513 non-null   int64
#  29  goalkeeping_diving          4513 non-null   int64
#  30  goalkeeping_handling        4513 non-null   int64
#  31  goalkeeping_kicking         4513 non-null   int64
#  32  goalkeeping_positioning     4513 non-null   int64
#  33  goalkeeping_reflexes        4513 non-null   int64
# dtypes: float64(1), int64(33)
# memory usage: 1.2 MB

# %%
df_skills=df_skills.drop(["defending_marking"], axis=1)

# %% [markdown]
# ## 3.-Exploratorio-Visual-para-Clustering

# %% [markdown]
# Visualizamos los datos de a dos variables numéricas
#
# **Consigna de trabajo en grupo:** buscar agrupamiento de datos usando las variables en skill_ratings de a pares

# %%
#data=[]
bool_crack=df_n["overall"] > 85 #diferenciamos a los mejores jugadores

#Elejimos dos variables, para esto elejimos dos números entre 0 y  de n_skills-1
skill_1=skills_ratings[6]
skill_2=skills_ratings[25]

# %% [markdown]
# Gráfica con matplotlib.pyplot, liviana pero más sencilla

# %%
plt.figure(figsize=(8,8), dpi=80)
plt.scatter(df_skills[skill_1], y=df_skills[skill_2],s=3,c=bool_crack)
plt.xlabel(skill_1)
plt.ylabel(skill_2)
plt.show()

# %% [markdown]
# Gráfica con Plotly, más completa e interactiva pero un poco pesada

# %%
graf1 = go.Scatter(x=df_skills[skill_1], y=df_skills[skill_2],
                           mode='markers',
                        text=df_n.loc[:,'club_name'], #'Height', 'Weight', 'Club', 'Age', 'Name','Position'
                           marker=dict(
                                size=5)
                           )

crack =go.Scatter(x=df_skills.loc[bool_crack,skill_1], y=df_skills.loc[bool_crack,skill_2],name='Top players',
                      text=df_n.loc[bool_crack,'short_name'],
                      textfont=dict(family='sans serif',size=10,color='black'),
                      opacity=0.9,mode='text')

data=[graf1,crack]

layout = go.Layout(title="Visualización de la base de a dos variables numéricas",titlefont=dict(size=20),
                xaxis=dict(title=skill_1),
                yaxis=dict(title=skill_2),
                autosize=False, width=700,height=700)

fig = go.Figure(data=data, layout=layout)

# %%
#En Jupyter Ntb abre en otra ventana, 
plot(fig)
# Out:
# 'temp-plot.html'

# %%
#en Jupyter Ntb, abre en la ntb
#iplot(fig)

# %% [markdown]
# **Consigna de trabajo en grupo:** buscar agrupamientos de jugadores de manera intuitiva por cercanía (en espacios bidimensionales, de a dos variables por vez) y si se encuentran, tratar de explicarlos visualmente con alguna característica.
#
# En próxima gráfica, similar a la anterior, también se diferencian los mejores jugadores y alguna característica de interés (que pueden cambiar)
#
# Se puede ubicar también un jugador en particular. Con la siguiente linea de comando, por ejemplo, Leo Messi:

# %%
#P/Gráfico 2

#Elegimos un jugador
recherche_joueur=df_n["short_name"]=='L. Messi' 
#recherche_joueur=df_n["Name"]==df_n["Name"][4000] # acá podemos elegir otro 

bool_crack=df_n["overall"] > 85
bool_elecc=df_n["club_name"]=='FC Barcelona' 
bool_no_crack=df_n["overall"]<86
bool_machinegun=df_n["short_name"]=='MachineGun'

#Elegir dos números entre 0 y  de n_skills-1
skill_1=skills_ratings[6]  #6
skill_2=skills_ratings[25]  #25

# %% [markdown]
# Gráfica con plotly

# %%
palette=['navy','red','#A2D5F2','orange','green','pink']  

data=[]

n_crack =go.Scatter(x=df_skills.loc[bool_crack,skill_1], y=df_skills.loc[bool_crack,skill_2],name='Crack',
                      text=df_n.loc[bool_crack,'short_name'],
                      textfont=dict(family='sans serif',size=15,color='black'),
                      opacity=0.9,marker=dict(color=palette[2],size=7),mode='markers+text')

n_no_crack =go.Scatter(x=df_skills.loc[bool_no_crack,skill_1], y=df_skills.loc[bool_no_crack,skill_2],name='Average player',
                         text=df_n.loc[bool_no_crack,'short_name'],
                         opacity=0.6,marker=dict(color=palette[1],size=3),mode='markers')
n_elecc=go.Scatter(x=df_skills.loc[bool_elecc,skill_1], y=df_skills.loc[bool_elecc,skill_2],name='Elección',
                         text=df_n.loc[bool_elecc,'short_name'],
                         opacity=0.6,marker=dict(color=palette[0],size=5),mode='markers')

n_machinegun =go.Scatter(x=df_skills.loc[bool_machinegun,skill_1], y=df_skills.loc[bool_machinegun,skill_2],name='Perfect player',
                           textfont=dict(family='sans serif',size=20,color='black'),
                           opacity=0.6,marker=dict(color=palette[3],size=30),mode='markers+text')


joueur_recherche =go.Scatter(x=df_skills.loc[recherche_joueur,skill_1], y=df_skills.loc[recherche_joueur,skill_2],name='Searched player',
                           text=df_n.loc[recherche_joueur,'short_name'],
                            textfont=dict(family='sans serif',size=20,color='black'),
                           opacity=1,marker=dict(color=palette[4],size=40),mode='markers+text')

data=[n_no_crack,n_elecc
      ,n_crack,n_machinegun,joueur_recherche]

layout = go.Layout(title="Fifa Players",titlefont=dict(size=20),
                xaxis=dict(title=skill_1),
                yaxis=dict(title=skill_2),
                autosize=False, width=1000,height=1000)

fig = go.Figure(data=data, layout=layout)

# %%
#En Colab
#fig.show(renderer="colab")

# %%
#En Jupyter ntb
plot(fig) #abre y muestra en otra pestaña
#iplot(fig)  #muestra aquí
# Out:
# 'temp-plot.html'

# %% [markdown]
# **Identifiquemos algunos jugadores por nombre**

# %%
print(df_n.loc[0:43,"short_name"])
# Out:
# 0                L. Messi
# 1       Cristiano Ronaldo
# 2                J. Oblak
# 3          R. Lewandowski
# 4               Neymar Jr
# 5            K. De Bruyne
# 6               K. Mbappé
# 7           M. ter Stegen
# 8             V. van Dijk
# 9                 Alisson
# 10                S. Mané
# 11               M. Salah
# 12            T. Courtois
# 13              S. Agüero
# 14           Sergio Ramos
# 15             K. Benzema
# 16               M. Neuer
# 17               Casemiro
# 18                Ederson
# 19            R. Sterling
# 20             J. Kimmich
# 21                H. Kane
# 22              P. Dybala
# 23          S. Handanovič
# 24               T. Kroos
# 25              E. Hazard
# 26           K. Koulibaly
# 27               N. Kanté
# 28              J. Sancho
# 29    T. Alexander-Arnold
# 30        Bruno Fernandes
# 31             A. Laporte
# 32                Fabinho
# 33           A. Robertson
# 34         Bernardo Silva
# 35           G. Chiellini
# 36              H. Lloris
# 37              L. Suárez
# 38              L. Modrić
# 39            A. Di María
# 40            W. Szczęsny
# 41          P. Aubameyang
# 42        Sergio Busquets
# 43            C. Immobile
# Name: short_name, dtype: object

# %%
#data=[]
bool_crack=df_n["overall"] > 85 #diferenciamos a los mejores jugadores
skill_3=skills_ratings[5]
skill_4=skills_ratings[21]

# %%
graf2 = go.Scatter(x=df_skills[skill_3], y=df_skills[skill_4],
                           mode='markers',
                        text=df_n.loc[:,'club_name'], #'Height', 'Weight', 'Club', 'Age', 'Name','Position'
                           marker=dict(
                                size=5)
                           )

crack =go.Scatter(x=df_skills.loc[bool_crack,skill_3], y=df_skills.loc[bool_crack,skill_4],name='Top players',
                      text=df_n.loc[bool_crack,'short_name'],
                      textfont=dict(family='sans serif',size=10,color='black'),
                      opacity=0.9,mode='text')

data=[graf2,crack]

layout = go.Layout(title="Visualización de la base de a dos variables numéricas",titlefont=dict(size=20),
                xaxis=dict(title=skill_3),
                yaxis=dict(title=skill_4),
                autosize=False, width=700,height=700)

fig = go.Figure(data=data, layout=layout)

# %%
#En Jupyter Ntb abre en otra ventana, 
plot(fig)
# Out:
# 'temp-plot.html'

# %%
#data=[]
bool_crack=df_n["overall"] > 85 #diferenciamos a los mejores jugadores
skill_5=skills_ratings[20]
skill_6=skills_ratings[3]

# %%
graf3 = go.Scatter(x=df_skills[skill_5], y=df_skills[skill_6],
                           mode='markers',
                        text=df_n.loc[:,'club_name'], #'Height', 'Weight', 'Club', 'Age', 'Name','Position'
                           marker=dict(
                                size=5)
                           )

crack =go.Scatter(x=df_skills.loc[bool_crack,skill_5], y=df_skills.loc[bool_crack,skill_6],name='Top players',
                      text=df_n.loc[bool_crack,'short_name'],
                      textfont=dict(family='sans serif',size=10,color='black'),
                      opacity=0.9,mode='text')

data=[graf3,crack]

layout = go.Layout(title="Visualización de la base de a dos variables numéricas",titlefont=dict(size=20),
                xaxis=dict(title=skill_5),
                yaxis=dict(title=skill_6),
                autosize=False, width=700,height=700)

fig = go.Figure(data=data, layout=layout)

# %%
#En Jupyter Ntb abre en otra ventana, 
plot(fig)
# Out:
# 'temp-plot.html'

# %%
#data=[]
bool_crack=df_n["overall"] > 85 #diferenciamos a los mejores jugadores
skill_7=skills_ratings[2]
skill_8=skills_ratings[27]

# %%
graf4 = go.Scatter(x=df_skills[skill_7], y=df_skills[skill_8],
                           mode='markers',
                        text=df_n.loc[:,'club_name'], #'Height', 'Weight', 'Club', 'Age', 'Name','Position'
                           marker=dict(
                                size=5)
                           )

crack =go.Scatter(x=df_skills.loc[bool_crack,skill_7], y=df_skills.loc[bool_crack,skill_8],name='Top players',
                      text=df_n.loc[bool_crack,'short_name'],
                      textfont=dict(family='sans serif',size=10,color='black'),
                      opacity=0.9,mode='text')

data=[graf4,crack]

layout = go.Layout(title="Visualización de la base de a dos variables numéricas",titlefont=dict(size=20),
                xaxis=dict(title=skill_7),
                yaxis=dict(title=skill_8),
                autosize=False, width=700,height=700)

fig = go.Figure(data=data, layout=layout)

# %%
#En Jupyter Ntb abre en otra ventana, 
plot(fig)
# Out:
# 'temp-plot.html'

# %%
#data=[]
bool_crack=df_n["overall"] > 85 #diferenciamos a los mejores jugadores
skill_9=skills_ratings[20]
skill_10=skills_ratings[1]

# %%
graf5 = go.Scatter(x=df_skills[skill_7], y=df_skills[skill_8],
                           mode='markers',
                        text=df_n.loc[:,'club_name'], #'Height', 'Weight', 'Club', 'Age', 'Name','Position'
                           marker=dict(
                                size=5)
                           )

crack =go.Scatter(x=df_skills.loc[bool_crack,skill_9], y=df_skills.loc[bool_crack,skill_10],name='Top players',
                      text=df_n.loc[bool_crack,'short_name'],
                      textfont=dict(family='sans serif',size=10,color='black'),
                      opacity=0.9,mode='text')

data=[graf5,crack]

layout = go.Layout(title="Visualización de la base de a dos variables numéricas",titlefont=dict(size=20),
                xaxis=dict(title=skill_9),
                yaxis=dict(title=skill_10),
                autosize=False, width=700,height=700)

fig = go.Figure(data=data, layout=layout)

# %%
#En Jupyter Ntb abre en otra ventana, 
plot(fig)
# Out:
# 'temp-plot.html'
